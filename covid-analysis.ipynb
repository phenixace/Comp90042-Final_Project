# %%
import os
import re
import json
import nltk
import string
import enchant
import numpy as np
import pandas as pd
import seaborn as sns
from PIL import Image
from datetime import datetime
import matplotlib.pyplot as plt
from collections import Counter
from wordcloud import WordCloud
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer 
from nltk.tokenize import RegexpTokenizer
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# #### Data Inspection

# %%
covid_data = pd.read_csv('covid19_tweets.csv', encoding='utf-8')
covid_label = pd.read_csv('covid19_tweets_processed.csv')
covid_data = pd.concat([covid_data, covid_label], axis=1)
covid_data.columns
# Out:
# Index(['user_name', 'user_location', 'user_description', 'user_created',
#        'user_followers', 'user_friends', 'user_favourites', 'user_verified',
#        'date', 'text', 'hashtags', 'source', 'is_retweet', 'label'],
#       dtype='object')

# %%
covid_data.head()
# Out:
#          user_name         user_location  \
# 0           ᏉᎥ☻լꂅϮ            astroworld
# 1    Tom Basile 🇺🇸          New York, NY
# 2  Time4fisticuffs      Pewee Valley, KY
# 3      ethel mertz  Stuck in the Middle
# 4         DIPR-J&K     Jammu and Kashmir
#
#                                     user_description         user_created  \
# 0  wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2  #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 3  #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 4  🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             624           950            18775          False
# 1            2253          1677               24           True
# 2            9275          9525             7254          False
# 3             197           987             1488          False
# 4          101009           168              101          False
#
#                   date                                               text  \
# 0  2020-07-25 12:27:21  If I smelled the scent of hand sanitizers toda...
# 1  2020-07-25 12:27:17  Hey @Yankees @YankeesPR and @MLB - wouldn't it...
# 2  2020-07-25 12:27:14  @diane3443 @wdunlap @realDonaldTrump Trump nev...
# 3  2020-07-25 12:27:10  @brookbanktv The one gift #COVID19 has give me...
# 4  2020-07-25 12:27:08  25 July : Media Bulletin on Novel #CoronaVirus...
#
#                             hashtags               source  is_retweet  label
# 0                                NaN   Twitter for iPhone       False      0
# 1                                NaN  Twitter for Android       False      0
# 2                        ['COVID19']  Twitter for Android       False      1
# 3                        ['COVID19']   Twitter for iPhone       False      0
# 4  ['CoronaVirusUpdates', 'COVID19']  Twitter for Android       False      0

# %% [markdown]
# #### Data Cleaning

# %%
# clean @at, namely clean username
def clean_at(data):
    return re.sub('@[^\s]+', ' ', data)

# clean URLs
def clean_URLs(data):
    return re.sub('((www\.[^\s]+)|(https?://[^\s]+))',' ',data)

# clean numbers
def clean_numbers(data):
    return re.sub('[0-9]+', '', data)

def clean_emojis(data):
    emoj = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF"  # chinese char
        u"\U00002702-\U000027B0"
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642" 
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"  # dingbats
        u"\u3030"
                      "]+", re.UNICODE)
    return re.sub(emoj, '', data)
    

# clean non-english words
def clean_non_english_word(data):
    d = enchant.Dict('en_US') # english dictionary
    return ' '.join([word for word in data.split() if d.check(word)])

from nltk.corpus import stopwords
stopwords = set(stopwords.words('english'))
def clean_stopwords(data):
    return ' '.join([word for word in data.split() if word not in stopwords])

def clean_punctuations(data):
    punctuations_list = string.punctuation
    translator = str.maketrans('', '', punctuations_list)
    return data.translate(translator)

# stemming
def stemming(data):
    st = PorterStemmer()
    return ' '.join([st.stem(word) for word in data.split()])

# Lemmatization
def lemmatization(data):
    wnl = WordNetLemmatizer()
    return ' '.join([wnl.lemmatize(word) for word in data.split()])

# %%
covid_data['text'] = covid_data['text'].str.lower()
covid_data['text'] = covid_data['text'].apply(lambda x:clean_at(x))
covid_data['text'] = covid_data['text'].apply(lambda x:clean_URLs(x))
covid_data['text'] = covid_data['text'].apply(lambda x:clean_emojis(x))
covid_data['text'] = covid_data['text'].str.replace("[^a-zA-Z#]", " ")
covid_data['text'] = covid_data['text'].str.replace(r'\B#\w*[a-zA-Z]+\w*', '')
covid_data['text'] = covid_data['text'].str.replace('@[A-Za-z0-9]+', '') 
covid_data['text'] = covid_data['text'].str.replace('\n', ' ') 
covid_data['text'] = covid_data['text'].apply(lambda x: clean_non_english_word(x))
covid_data['text'] = covid_data['text'].apply(lambda x: clean_stopwords(x))
covid_data['text'] = covid_data['text'].apply(lambda x: clean_punctuations(x))
covid_data['text'] = covid_data['text'].apply(lambda x: lemmatization(x))
covid_data['text'].head()
# Out:
# /var/folders/xl/l07cxwy94pgcqqp6n3npqbt80000gn/T/ipykernel_5249/2810399161.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   covid_data['text'] = covid_data['text'].str.replace("[^a-zA-Z#]", " ")
# /var/folders/xl/l07cxwy94pgcqqp6n3npqbt80000gn/T/ipykernel_5249/2810399161.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   covid_data['text'] = covid_data['text'].str.replace(r'\B#\w*[a-zA-Z]+\w*', '')
# /var/folders/xl/l07cxwy94pgcqqp6n3npqbt80000gn/T/ipykernel_5249/2810399161.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   covid_data['text'] = covid_data['text'].str.replace('@[A-Za-z0-9]+', '')
# 0    smelled scent hand sanitizers today someone pa...
# 1                    hey made sense player pay respect
# 2                trump never claimed hoax claim effort
# 3    one gift give appreciation simple thing always...
# 4                                medium bulletin novel
# Name: text, dtype: object

# %%
covid_data['user_description'] = covid_data['user_description'].replace(np.nan, '', regex=True)
covid_data['user_description'] = covid_data['user_description'].str.lower()
covid_data['user_description'] = covid_data['user_description'].apply(lambda x:clean_at(x))
covid_data['user_description'] = covid_data['user_description'].apply(lambda x:clean_URLs(x))
covid_data['user_description'] = covid_data['user_description'].apply(lambda x:clean_emojis(x))
covid_data['user_description'] = covid_data['user_description'].str.replace("[^a-zA-Z#]", " ")
covid_data['user_description'] = covid_data['user_description'].str.replace(r'\B#\w*[a-zA-Z]+\w*', '')
covid_data['user_description'] = covid_data['user_description'].str.replace('@[A-Za-z0-9]+', '') 
covid_data['user_description'] = covid_data['user_description'].str.replace('\n', ' ') 
covid_data['user_description'] = covid_data['user_description'].apply(lambda x: clean_non_english_word(x))
covid_data['user_description'] = covid_data['user_description'].apply(lambda x: clean_stopwords(x))
covid_data['user_description'] = covid_data['user_description'].apply(lambda x: clean_punctuations(x))
covid_data['user_description'] = covid_data['user_description'].apply(lambda x: lemmatization(x))
covid_data['user_description'].head()
# Out:
# /var/folders/xl/l07cxwy94pgcqqp6n3npqbt80000gn/T/ipykernel_5249/2674251387.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   covid_data['user_description'] = covid_data['user_description'].str.replace("[^a-zA-Z#]", " ")
# /var/folders/xl/l07cxwy94pgcqqp6n3npqbt80000gn/T/ipykernel_5249/2674251387.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   covid_data['user_description'] = covid_data['user_description'].str.replace(r'\B#\w*[a-zA-Z]+\w*', '')
# /var/folders/xl/l07cxwy94pgcqqp6n3npqbt80000gn/T/ipykernel_5249/2674251387.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   covid_data['user_description'] = covid_data['user_description'].str.replace('@[A-Za-z0-9]+', '')
# 0                                             princess
# 1    husband father columnist commentator author to...
# 2                                          sport lover
# 3
# 4    official twitter handle department information...
# Name: user_description, dtype: object

# %%
from transformers import pipeline
classifier = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english)

# %%
from tqdm import tqdm
sentiments = []
for i in tqdm(range(len(covid_data))):
    tweet = covid_data['text'][i]
    sentiment = classifier(tweet)[0]['label']
    sentiments.append(sentiment)

sentiments = pd.DataFrame(sentiments)
sentiments.columns = ['sentiment']
# Out:
# 100%|██████████| 179108/179108 [4:32:45<00:00, 10.94it/s]

# %%
df = pd.DataFrame(sentiments)
df.to_csv('sentiment.csv', index=False)

# %%
covid_data = pd.concat([covid_data, sentiments], axis=1)

# %%
rumours = covid_data[covid_data['label']==1]
rumours = rumours.reset_index(drop=True)
nonrumours = covid_data[covid_data['label']==0]
nonrumours = nonrumours.reset_index(drop=True)

# %% [markdown]
# #### Frequency Visualization

# %% [markdown]
# #### Visualization Functions

# %%
def visualize_freq(set, factor, factor_type, top_cnt, label_type, output_fname):
    all_vals = []
    for i in range(len(set)):
        if factor == 'text' or factor == 'user_description':
            values = set[factor][i].split()
            # word
            if values != []:
                for val in values:
                    all_vals.append(val)
        
        if factor == 'hashtags':
            values = set[factor][i]
            if str(values) != 'nan':
                values = eval(values)
                for val in values:
                    all_vals.append(val)
        
        if factor == 'user_location':
            location = set[factor][i]
            if str(location) != 'nan':
                all_vals.append(location)

        if factor == 'user_verified' or factor == 'user_name' or factor == 'sentiment' or factor == 'source':
            verify = set[factor][i]
            all_vals.append(verify)

        if factor == 'user_created':
            created_date = set[factor][i]
            created_date = datetime.strptime(created_date, "%Y-%m-%d %H:%M:%S")
            created_date = created_date.strftime('%Y')
            if created_date not in all_vals:
                all_vals.append(created_date)
            

    counter = Counter(all_vals)
    vals = list(counter.keys())
    freqs = list(counter.values())

    vals_freqs = pd.DataFrame([freqs]).T
    vals_freqs.columns = ['frequency']
    vals_freqs.index = vals
    vals_freqs = vals_freqs.sort_values('frequency', ascending=False)
    
    # top xxx frequent vals
    frequent_vals = vals_freqs['frequency'][:top_cnt].index

    # plot
    title = "{} Frequency in {} Tweets".format(factor_type, label_type)
    plt.figure(figsize=(12,20))
    plt.bar(np.arange(top_cnt), vals_freqs['frequency'][:top_cnt], width=0.8, color = sns.color_palette("bwr"), alpha=0.5, 
                edgecolor = "black", capsize=8, linewidth=1);
    plt.xticks(np.arange(top_cnt), frequent_vals, rotation=90, size=14);
    plt.xlabel("{} most frequent {}".format(str(top_cnt), factor_type), size=14, labelpad=6);
    plt.ylabel("Frequency", size=14, labelpad=6);
    plt.title(title, size=18)
    plt.grid(False);
    plt.gca().spines["top"].set_visible(False);
    plt.gca().spines["right"].set_visible(False);
    plt.savefig('images/'+output_fname, dpi=300, facecolor='w')
    plt.show()
    return frequent_vals

# %%
def visualize_wordcloud(wc_str, label_type, output_fname):
    mask = np.array(Image.open('images/twitter-icon.jpeg'))
    wc = WordCloud(background_color='white', colormap='Set1', mask=mask).generate(wc_str)
    title = '{} Tweets WordCloud'.format(label_type)
    plt.figure(figsize=(10,10), facecolor="w")
    plt.title(title, size=18)
    plt.imshow(wc, interpolation='bilinear')
    plt.axis("off")
    plt.savefig('images/'+output_fname, dpi=300)
    plt.show()

rumours_str = pd.Series(rumours['text']).str.cat(sep=' ')
nonrumours_str = pd.Series(nonrumours['text']).str.cat(sep=' ')

# %%
def visualize_distribution(set, factor, factor_type, top_cnt, set_type, output_fname):
    all_vals = []
    for i in range(len(set)):
        if factor == 'text':
            values = set[factor][i].split()
            # word
            if values != []:
                for val in values:
                    all_vals.append(val)
        
        if factor == 'hashtags':
            values = set[factor][i]
            if str(values) != 'nan':
                values = eval(values)
                for val in values:
                    all_vals.append(val)
        
        if factor == 'user_location':
            location = set[factor][i]
            if str(location) != 'nan':
                all_vals.append(location)
        
        if factor == 'user_verified' or factor == 'user_name' or factor == 'sentiment' or factor == 'source':
            verify = set[factor][i]
            all_vals.append(verify)

        if factor == 'user_created':
            created_date = set[factor][i]
            created_date = datetime.strptime(created_date, "%Y-%m-%d %H:%M:%S")
            created_date = created_date.strftime('%Y')
            all_vals.append(created_date)
    
    counter = Counter(all_vals)
    vals = list(counter.keys())
    freqs = list(counter.values())

    vals_freqs = pd.DataFrame([freqs]).T
    vals_freqs.columns = ['frequency']
    vals_freqs.index = vals
    vals_freqs = vals_freqs.sort_values('frequency', ascending=False)
    top_freqs = vals_freqs[:top_cnt]
    # top xxx frequent vals
    frequent_vals = top_freqs['frequency'].index

    # plot
    cmap = plt.get_cmap('RdPu')
    colors = [cmap(i) for i in np.linspace(0, 1, 8)]
    fig = top_freqs['frequency'].plot.pie(ylabel='', autopct='%1.1f%%', figsize=(10,10), colors=colors, 
    title='Top {} frequent {} Distribution in {} Tweets'.format(top_cnt, factor_type, set_type)).get_figure()
    fig.savefig('images/'+output_fname, dpi=300, facecolor='w')
    return top_freqs

# %% [markdown]
# #### Word Frequency Visualization

# %%
visualize_freq(covid_data, 'text', 'Word', 20, 'All', 'word-freq-all.png')
# Out:
# Index(['case', 'new', 'amp', 'death', 'people', 'u', 'day', 'pandemic', 'mask',
#        'one', 'need', 'today', 'positive', 'time', 'get', 'total', 'health',
#        'test', 'like', 'help'],
#       dtype='object')

# %%
visualize_freq(rumours, 'text', 'Word', 20, 'Rumours', 'word-freq-rumours.png')
# Out:
# Index(['trump', 'amp', 'people', 'u', 'like', 'death', 'one', 'get',
#        'pandemic', 'know', 'flu', 'say', 'time', 'world', 'day', 'president',
#        'go', 'lie', 'new', 'would'],
#       dtype='object')

# %%
visualize_freq(nonrumours, 'text', 'Word', 20, 'Non-Rumours', 'word-freq-nonrumours.png')
# Out:
# Index(['case', 'new', 'amp', 'death', 'people', 'u', 'day', 'pandemic', 'mask',
#        'positive', 'today', 'need', 'one', 'total', 'health', 'time', 'get',
#        'test', 'help', 'state'],
#       dtype='object')

# %% [markdown]
# #### Hashtag Frequency Visualization

# %%
visualize_freq(rumours, 'hashtags', 'Hashtag', 40, 'Rumours', 'hashtag-freq-rumours.png')
# Out:
# Index(['COVID19', 'Covid19', 'covid19', 'Trump', 'coronavirus', 'GOP', 'trump',
#        'pandemic', 'TrumpVirus', 'USA', 'MAGA', 'Coronavirus', 'Russia',
#        'DonaldTrump', 'China', 'Biden', 'BlackLivesMatter', 'Democrats',
#        'FakeNews', 'America', 'Trump2020', 'BLM', 'TrumpFailedAmerica',
#        'economy', 'KitaTeguhKitaMenang', 'MalaysiaPrihatin',
#        'KibarJalurGemilang', 'MalaysiakuMerdeka', 'MerdekaMoment',
#        'Republicans', 'Fauci', 'WearAMask', 'Hydroxychloroquine', 'Brexit',
#        'maga', 'news', 'Covid_19', 'India', 'flu', 'COVID'],
#       dtype='object')

# %%
visualize_freq(nonrumours, 'hashtags', 'Hashtag', 40, 'Non-Rumours', 'hashtag-freq-nonrumours.png')
# Out:
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 12540 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12540 missing from current font.
#   font.set_text(s, 0, flags=flags)
# Index(['COVID19', 'Covid19', 'covid19', 'coronavirus', 'Coronavirus',
#        'pandemic', 'India', 'CoronavirusPandemic', 'lockdown', 'corona',
#        'COVID', 'Odisha', 'CoronaVirusUpdate', 'WearAMask', 'vaccine',
#        'IndiaFightsCorona', 'CoronaVirusUpdates', 'Covid_19', 'CoronaVirus',
#        'Trump', 'China', 'CoronaInfoCH', 'Corona', 'COVIDー19', 'BREAKING',
#        'COVIDIOTS', 'USA', 'Blood', 'mask', 'StaySafe', 'Russia', 'Pandemic',
#        'covid', 'SocialDistancing', 'auspol', 'SARSCoV2', 'health', 'Florida',
#        'UK', 'COVID__19'],
#       dtype='object')

# %% [markdown]
# #### Word Cloud Visualization

# %%
visualize_wordcloud(rumours_str, 'Rumour', 'rumour-wc.png')

# %%
visualize_wordcloud(nonrumours_str, 'Non-Rumour', 'nonrumour-wc.png')

# %% [markdown]
# #### Rumours Topic Trends Overtime

# %%
covid_data['date'] = pd.to_datetime(covid_data['date'])
dates = []
for i in range(len(rumours)):
    date = rumours['date'][i]
    date = datetime.strptime(date, "%Y-%m-%d %H:%M:%S")
    date = date.strftime('%Y-%m-%d')
    if date not in dates:
        dates.append(date)

dates = sorted(dates)
periods = []
for i in range(4):
    period = dates[7*i:7*(i+1)]
    if i == 3:
        period = dates[21:]
    periods.append(period)

periods # 分成 7， 7， 7， 5这样四个阶段来看变化
# Out:
# [['2020-07-24',
#   '2020-07-25',
#   '2020-07-26',
#   '2020-07-27',
#   '2020-07-28',
#   '2020-07-29',
#   '2020-07-30'],
#  ['2020-07-31',
#   '2020-08-01',
#   '2020-08-02',
#   '2020-08-04',
#   '2020-08-06',
#   '2020-08-07',
#   '2020-08-08'],
#  ['2020-08-09',
#   '2020-08-10',
#   '2020-08-11',
#   '2020-08-12',
#   '2020-08-13',
#   '2020-08-14',
#   '2020-08-16'],
#  ['2020-08-17', '2020-08-18', '2020-08-22', '2020-08-29', '2020-08-30']]

# %%
for i in range(len(periods)):
    start_time = periods[i][0]
    end_time = periods[i][-1]
    mask = (covid_data['date'] > start_time) & (covid_data['date'] <= end_time)
    if i == 0:
        # 这里暂时hard code 上去
        period_1 = covid_data.loc[mask]
    if i == 1:
        period_2 = covid_data.loc[mask]
    if i == 2:
        period_3 = covid_data.loc[mask]
    if i == 3:
        period_4 = covid_data.loc[mask]

period_1 = period_1.reset_index(drop=True)
period_2 = period_2.reset_index(drop=True)
period_3 = period_3.reset_index(drop=True)
period_4 = period_4.reset_index(drop=True)

# %%
period_1_top_20_words = visualize_freq(period_1, 'text', 'Word', 20, 'from 2020-07-24 to 2020-07-30 Rumour', 'word-freq-rumour-period1.png')

# %%
period_2_top_20_words = visualize_freq(period_2, 'text', 'Word', 20, 'from 2020-07-31 to 2020-08-08 Rumour', 'word-freq-rumour-period2.png')

# %%
period_3_top_20_words = visualize_freq(period_3, 'text', 'Word', 20, 'from 2020-08-09 to 2020-08-16 Rumour', 'word-freq-rumour-period3.png')

# %%
period_4_top_20_words = visualize_freq(period_4, 'text', 'Word', 20, 'from 2020-08-17 to 2020-08-30 Rumour', 'word-freq-rumour-period4.png')

# %%
frequent_words = list(period_1_top_20_words)
words = list(period_1_top_20_words) + list(period_2_top_20_words) + list(period_3_top_20_words) + list(period_4_top_20_words)
for word in words:
    if word not in frequent_words:
        frequent_words.append(word)

def period_word_cnt(set, word):
    corpus = []
    for i in range(len(set)):
        tweet = set['text'][i].split()
        if tweet != []:
            for val in tweet:
                corpus.append(val)
    counter = Counter(corpus)
    res = counter[word]
    return res

period1_freqs = {}
for word in frequent_words:
    freq = period_word_cnt(period_1, word)
    period1_freqs[word] = freq
frequent_words = sorted(period1_freqs, key=period1_freqs.get, reverse=True)

# %%
periods_freqs = []
for word in frequent_words:
    instance = []
    for i in range(4):
        if i == 0:
            freq = period_word_cnt(period_1, word)
        if i == 1:
            freq = period_word_cnt(period_2, word)
        if i == 2:
            freq = period_word_cnt(period_3, word)
        if i == 3:
            freq = period_word_cnt(period_4, word)
        instance.append(freq)
    periods_freqs.append(instance)

periods_freqs = pd.DataFrame(periods_freqs)
periods_freqs.index = frequent_words
colums = ['Period1','Period2', 'Period3', 'Peroid4']
periods_freqs.columns = colums
periods_freqs
# Out:
#           Period1  Period2  Period3  Peroid4
# case         5579     3652     4654     3681
# new          3514     2916     3645     2756
# amp          3000     2884     3154     2080
# death        2463     1994     2122     1926
# people       2273     2032     2295     1590
# u            1946     1807     1856     1416
# day          1941     1272     1862     1172
# mask         1672     1342     1379      945
# positive     1651     1147     1029      749
# pandemic     1530     1556     1753     1327
# total        1432      848      994      925
# one          1251     1256     1342      940
# need         1247     1259     1155      899
# get          1198     1135     1137      907
# today        1147     1210     1308      925
# time         1144     1132     1173      928
# health       1105     1123     1230      895
# state        1070      914      897      619
# test         1060     1005     1055      803
# number       1027      731      784      656
# like         1012      980      913      746
# update        986      779      796      751
# help          959      962      954      742
# say           895      816     1034      619
# world         784      678     1257      585
# first         703      572     1067      418
# school        638     1047      955      653
# vaccine       565      580     1366      443

# %%
X = frequent_words 
y_period1 = list(periods_freqs['Period1'])
y_period2 = list(periods_freqs['Period2'])
y_period3 = list(periods_freqs['Period3'])
y_period4 = list(periods_freqs['Peroid4'])

X_axis = np.arange(len(X))
plt.figure(figsize=(40, 12))
plt.vlines(X_axis - 0.2, y_period1, 0.1, label = '2020-07-24 to 2020-07-30', color = 'purple')
plt.vlines(X_axis - 0.1, y_period2, 0.1, label = '2020-07-31 to 2020-08-08', color = 'red')
plt.vlines(X_axis + 0.1, y_period3 , 0.1, label = '2020-08-09 to 2020-08-16', color = 'orange')
plt.vlines(X_axis + 0.2, y_period4, 0.1, label = '2020-08-17 to 2020-08-30', color = 'pink')
plt.xticks(X_axis, X, size=16)
plt.xlabel("Rumour Topic", size=24, labelpad=30)
plt.ylabel("Word Frequency", size=24, labelpad=30)
plt.title("Rumours Topic Trends Overtime", size=38)
plt.legend(fontsize=26)
plt.gca().spines["top"].set_visible(False)
plt.gca().spines["right"].set_visible(False)
plt.savefig('images/trend.png', dpi=300, facecolor='w')
plt.show()

# %% [markdown]
# #### Characteristics of Rumour-Creating Users Analysis

# %% [markdown]
# What are the characteristics of rumour-creating users, and are they different to normal users?

# %% [markdown]
# * user_name: 这个应该很难分析
# * user_location: 地点频率分析， 地点distribution bar chart
# * user_description 可以做文本分析 freq
# * user_created 账号创建的时间， 发布谣言是不是新的账号
# * user_followers -- 粉丝数，rumour粉丝数的主要区间
# * user_friends: 朋友个数？
# * user_favourites: 点赞
# * user_verified: True False

# %%
covid_data.columns
# Out:
# Index(['user_name', 'user_location', 'user_description', 'user_created',
#        'user_followers', 'user_friends', 'user_favourites', 'user_verified',
#        'date', 'text', 'hashtags', 'source', 'is_retweet', 'label'],
#       dtype='object')

# %%
rumours
# Out:
#                         user_name              user_location  \
# 0                 Time4fisticuffs           Pewee Valley, KY
# 1            🏳️‍🌈Heath Walker🏳️‍🌈                 Larose, LA
# 2                 Charles Mapundu    England, United Kingdom
# 3                 anonymous bosch  816 ways to say 'midwest'
# 4              Eric aka Chewy Red          Pennsylvania, USA
# ...                           ...                        ...
# 14858                 RoaringLion               Georgia, USA
# 14859  Donahue Rogers Ex-Labour 🥀              North England
# 14860             Cure Cancer Now          Microtitre Plates
# 14861                 raincoaster            Ottawa, Ontario
# 14862                 🦋  ROGUE  🦋                        NaN
#
#                                         user_description         user_created  \
# 0                                            sport lover  2009-02-28 18:57:41
# 1                                         single gay lib  2012-07-27 13:54:06
# 2      thing desired lord seek may dwell house lord d...  2013-08-22 23:18:21
# 3      chef food writer hedonist misanthrope given fo...  2009-07-13 08:31:12
# 4      middle ground gun issue carry protect loved on...  2013-01-27 18:17:29
# ...                                                  ...                  ...
# 14858                               democratic value win  2017-10-02 04:47:49
# 14859                                   socialist former  2011-07-11 21:01:12
# 14860  pure science taking defeat cancer receive best...  2010-09-22 13:22:35
# 14861          called cool anarchist activist journalist  2008-07-24 08:37:54
# 14862  may aching heart find way patience self seeing...  2017-01-30 07:38:23
#
#        user_followers  user_friends  user_favourites  user_verified  \
# 0                9275          9525             7254          False
# 1                 594          1012            37279          False
# 2                  11            40              192          False
# 3                 695          1836             2826          False
# 4                  66           420              586          False
# ...               ...           ...              ...            ...
# 14858              35           189             3911          False
# 14859            4071          4318             8332          False
# 14860            7569          7835                1          False
# 14861           13542         11809             9898          False
# 14862             628           386            14845          False
#
#                       date                                               text  \
# 0      2020-07-25 12:27:14              trump never claimed hoax claim effort
# 1      2020-07-25 12:25:46  economy budget tied oil like funny right wing ...
# 2      2020-07-25 12:25:21                                       video stitch
# 3      2020-07-25 12:25:18  look micro dick go astounding achievement bril...
# 4      2020-07-25 12:25:12  concealed nation million giveaway put family s...
# ...                    ...                                                ...
# 14858  2020-08-29 19:45:51  getting beaten like dog poll sadly failed reac...
# 14859  2020-08-29 19:45:38                                   govt nothing flu
# 14860  2020-08-29 19:45:28  happy ending justly scorned misrepresentation ...
# 14861  2020-08-29 19:45:24  get discount million dollar government money t...
# 14862  2020-08-29 19:44:51           family contributed already life lost amp
#
#                                                 hashtags               source  \
# 0                                            ['COVID19']  Twitter for Android
# 1                                                    NaN  Twitter for Android
# 2      ['obesity', 'زواج_راكان_الحربي', 'carryminati'...  Twitter for Android
# 3                                                    NaN   Twitter for iPhone
# 4                                                    NaN      Twitter Web App
# ...                                                  ...                  ...
# 14858                                   ['LawlessTrump']   Twitter for iPhone
# 14859                                                NaN      Twitter Web App
# 14860                                                NaN      Twitter Web App
# 14861                                                NaN  Twitter for Android
# 14862                                          ['Trump']  Twitter for Android
#
#        is_retweet  label
# 0           False      1
# 1           False      1
# 2           False      1
# 3           False      1
# 4           False      1
# ...           ...    ...
# 14858       False      1
# 14859       False      1
# 14860       False      1
# 14861       False      1
# 14862       False      1
#
# [14863 rows x 14 columns]

# %% [markdown]
# ##### User Analysis

# %%
visualize_freq(rumours, 'user_name', 'User', 20, 'Rumour', 'usr-freq-rumour.png')
# Out:
# Index(['GlobalPandemic.NET', 'Social Distance Warrior', 'Hotpage News',
#        'PMR DUNGUN', 'Mom3andRN', 'TornadoNewsLinker', 'Open Letters',
#        'National Cyber Security', 'James Starvoice', 'Slim and Sugar',
#        '@holiness #VoteBlueNoMatterWho', '8min 46sec',
#        'www.THEPIGEONEXPRESS.com', 'Teddi Fishman 🧑🏽 👩🏾 👨🏻 📷 📺 (she/her)',
#        'LynnZ', 'ChimpReports', 'Real business info', 'CricketDiane',
#        'Liu Bao Bei', 'Roberto Jones'],
#       dtype='object')

# %%
visualize_freq(nonrumours, 'user_name', 'User', 20, 'Non-Rumour', 'usr-freq-nonrumour.png')
# Out:
# Index(['Coronavirus Updates', 'GlobalPandemic.NET', 'covidnews.ch',
#        'Open Letters', 'Blood Donors India', 'Hindustan Times', 'IAM Platform',
#        'Paperbirds_Coronavirus', 'IANS Tweets', 'ANI',
#        'Coronavirus Updates - Alexander Higgins', 'OTV', 'Dushyant Vachhani',
#        'ABS-CBN News', 'Covid Data', '#IndiaFightsCorona',
#        'The New Indian Express', 'COVID Scale', 'APO Group English',
#        'Sambad English'],
#       dtype='object')

# %%
rumours_creators = visualize_distribution(rumours, 'user_name', 'User', 20, 'Rumour', 'usr-rumour-bar.png')
rumours_creators
# Out:
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 129489 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 127997 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128105 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 127998 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128104 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 127995 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128247 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128250 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 129489 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 127997 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128105 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 127998 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128104 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 127995 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128247 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128250 missing from current font.
#   font.set_text(s, 0, flags=flags)
#                                       frequency
# GlobalPandemic.NET                           73
# Social Distance Warrior                      66
# Hotpage News                                 46
# PMR DUNGUN                                   40
# Mom3andRN                                    30
# TornadoNewsLinker                            27
# Open Letters                                 22
# National Cyber Security                      21
# James Starvoice                              21
# Slim and Sugar                               21
# @holiness #VoteBlueNoMatterWho               20
# 8min 46sec                                   20
# www.THEPIGEONEXPRESS.com                     17
# Teddi Fishman 🧑🏽 👩🏾 👨🏻 📷 📺 (she/her)         16
# LynnZ                                        16
# ChimpReports                                 15
# Real business info                           15
# CricketDiane                                 15
# Liu Bao Bei                                  15
# Roberto Jones                                15
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 129489 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 127997 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128105 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 127998 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128104 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 127995 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128247 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128250 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 129489 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 127997 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128105 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 127998 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128104 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 127995 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128247 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/sw/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128250 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
nonrumours_creators = visualize_distribution(nonrumours, 'user_name', 'User', 20, 'Non-Rumour', 'usr-nonrumour-bar.png')
nonrumours_creators
# Out:
#                                          frequency
# Coronavirus Updates                            625
# GlobalPandemic.NET                             606
# covidnews.ch                                   401
# Open Letters                                   368
# Blood Donors India                             282
# Hindustan Times                                271
# IAM Platform                                   255
# Paperbirds_Coronavirus                         253
# IANS Tweets                                    238
# ANI                                            233
# Coronavirus Updates - Alexander Higgins        225
# OTV                                            218
# Dushyant Vachhani                              211
# ABS-CBN News                                   209
# Covid Data                                     208
# #IndiaFightsCorona                             199
# The New Indian Express                         195
# COVID Scale                                    191
# APO Group English                              179
# Sambad English                                 176

# %%
r_creators = list(rumours_creators.index)
r_creators_records = rumours[rumours['user_name'].isin(r_creators)]
r_creators_records = r_creators_records.drop_duplicates(subset='user_name', keep='first')
r_creators_records.index = r_creators_records.user_name
r_creators_records = r_creators_records.reindex(r_creators)
r_creators_records = pd.concat([rumours_creators, r_creators_records], axis=1)
r_creators_records

# 经常造谣的人只有2个人有认证
# 粉丝数没有超过10万
# Out:
#                                       frequency  \
# GlobalPandemic.NET                           73
# Social Distance Warrior                      66
# Hotpage News                                 46
# PMR DUNGUN                                   40
# Mom3andRN                                    30
# TornadoNewsLinker                            27
# Open Letters                                 22
# National Cyber Security                      21
# James Starvoice                              21
# Slim and Sugar                               21
# @holiness #VoteBlueNoMatterWho               20
# 8min 46sec                                   20
# www.THEPIGEONEXPRESS.com                     17
# Teddi Fishman 🧑🏽 👩🏾 👨🏻 📷 📺 (she/her)         16
# LynnZ                                        16
# ChimpReports                                 15
# Real business info                           15
# CricketDiane                                 15
# Liu Bao Bei                                  15
# Roberto Jones                                15
#
#                                                                  user_name  \
# GlobalPandemic.NET                                      GlobalPandemic.NET
# Social Distance Warrior                            Social Distance Warrior
# Hotpage News                                                  Hotpage News
# PMR DUNGUN                                                      PMR DUNGUN
# Mom3andRN                                                        Mom3andRN
# TornadoNewsLinker                                        TornadoNewsLinker
# Open Letters                                                  Open Letters
# National Cyber Security                            National Cyber Security
# James Starvoice                                            James Starvoice
# Slim and Sugar                                              Slim and Sugar
# @holiness #VoteBlueNoMatterWho              @holiness #VoteBlueNoMatterWho
# 8min 46sec                                                      8min 46sec
# www.THEPIGEONEXPRESS.com                          www.THEPIGEONEXPRESS.com
# Teddi Fishman 🧑🏽 👩🏾 👨🏻 📷 📺 (she/her)  Teddi Fishman 🧑🏽 👩🏾 👨🏻 📷 📺 (she/her)
# LynnZ                                                                LynnZ
# ChimpReports                                                  ChimpReports
# Real business info                                      Real business info
# CricketDiane                                                  CricketDiane
# Liu Bao Bei                                                    Liu Bao Bei
# Roberto Jones                                                Roberto Jones
#
#                                                       user_location  \
# GlobalPandemic.NET                                        WORLDWIDE
# Social Distance Warrior                                         NaN
# Hotpage News                                          United States
# PMR DUNGUN                                       Dungun, Terengganu
# Mom3andRN                                                       NaN
# TornadoNewsLinker                     Londonderry, Northern Ireland
# Open Letters                                   Text RESIST to 50409
# National Cyber Security                                 Atlanta, GA
# James Starvoice                                       San Diego, CA
# Slim and Sugar                                  South West, England
# @holiness #VoteBlueNoMatterWho                    Wichita Falls, TX
# 8min 46sec                                                 Canberra
# www.THEPIGEONEXPRESS.com                                     online
# Teddi Fishman 🧑🏽 👩🏾 👨🏻 📷 📺 (she/her)            South Carolina, USA
# LynnZ                                                           NaN
# ChimpReports                                                 Uganda
# Real business info                                       Etats-Unis
# CricketDiane                                 Staten Island, NY, USA
# Liu Bao Bei                                                     NaN
# Roberto Jones                           corrupt, criminal australia
#
#                                                                        user_description  \
# GlobalPandemic.NET                    breaking news critical information survive out...
# Social Distance Warrior                                                 believe science
# Hotpage News                                                           top headline day
# PMR DUNGUN
# Mom3andRN                             mph specialty yr infectious disease therapy ig...
# TornadoNewsLinker
# Open Letters                          copy real letter delivered president congress ...
# National Cyber Security                               leader download national security
# James Starvoice                                                      defying impossible
# Slim and Sugar                        hi thanks dropping sell vintage antique seeker...
# @holiness #VoteBlueNoMatterWho        many actually led spirit god son god holiness ...
# 8min 46sec                                                         twitter vice cartoon
# www.THEPIGEONEXPRESS.com                                  pigeon express news feed loop
# Teddi Fishman 🧑🏽 👩🏾 👨🏻 📷 📺 (she/her)    proud resister reformer free peace none u truly
# LynnZ                                 alum real estate developer designer accidental...
# ChimpReports                          preferred source instant news east call u comp...
# Real business info                    many different possibility start online busine...
# CricketDiane                          curated news feed retweet comment cricket hous...
# Liu Bao Bei                                                  human good going take work
# Roberto Jones                         human right universal la la miner refugee phot...
#
#                                              user_created  user_followers  \
# GlobalPandemic.NET                    2010-07-13 21:58:05           26108
# Social Distance Warrior               2020-04-15 14:12:10               2
# Hotpage News                          2009-03-12 14:16:30           26296
# PMR DUNGUN                            2018-07-17 03:32:33             199
# Mom3andRN                             2014-06-14 02:08:51              53
# TornadoNewsLinker                     2016-04-23 15:30:03            4711
# Open Letters                          2017-12-06 22:18:07           17161
# National Cyber Security               2010-01-27 22:48:24            5426
# James Starvoice                       2017-06-26 00:51:40             114
# Slim and Sugar                        2015-12-06 23:16:15            3050
# @holiness #VoteBlueNoMatterWho        2019-07-25 15:30:24             400
# 8min 46sec                            2011-09-14 02:31:09            7018
# www.THEPIGEONEXPRESS.com              2018-10-30 05:54:46            1026
# Teddi Fishman 🧑🏽 👩🏾 👨🏻 📷 📺 (she/her)  2009-06-08 02:19:38            6718
# LynnZ                                 2015-09-17 02:09:12           28488
# ChimpReports                          2011-10-10 16:45:59           78124
# Real business info                    2017-07-14 10:36:10            1336
# CricketDiane                          2010-08-01 21:50:10            2594
# Liu Bao Bei                           2020-04-02 22:00:20             105
# Roberto Jones                         2009-07-11 12:21:29            3103
#
#                                       user_friends  user_favourites  \
# GlobalPandemic.NET                           26003                2
# Social Distance Warrior                          4                0
# Hotpage News                                 13318                1
# PMR DUNGUN                                     517            17545
# Mom3andRN                                      152             6607
# TornadoNewsLinker                             4442           137297
# Open Letters                                     3                2
# National Cyber Security                        161                8
# James Starvoice                                348             1340
# Slim and Sugar                                4990            44559
# @holiness #VoteBlueNoMatterWho                 798              132
# 8min 46sec                                    2190            25897
# www.THEPIGEONEXPRESS.com                       109             4109
# Teddi Fishman 🧑🏽 👩🏾 👨🏻 📷 📺 (she/her)          7281            25704
# LynnZ                                        18845           160631
# ChimpReports                                  1105             1565
# Real business info                            3126              351
# CricketDiane                                  4978           234640
# Liu Bao Bei                                     75             4452
# Roberto Jones                                 1125            94651
#
#                                       user_verified                 date  \
# GlobalPandemic.NET                            False  2020-07-25 10:55:22
# Social Distance Warrior                       False  2020-07-25 11:15:42
# Hotpage News                                  False  2020-07-25 02:36:49
# PMR DUNGUN                                    False  2020-08-09 09:04:52
# Mom3andRN                                     False  2020-07-28 05:48:13
# TornadoNewsLinker                             False  2020-07-31 17:12:43
# Open Letters                                   True  2020-07-25 02:59:55
# National Cyber Security                       False  2020-07-25 09:48:44
# James Starvoice                               False  2020-07-25 07:37:40
# Slim and Sugar                                False  2020-08-08 13:10:03
# @holiness #VoteBlueNoMatterWho                False  2020-07-27 02:00:56
# 8min 46sec                                    False  2020-07-25 03:02:58
# www.THEPIGEONEXPRESS.com                      False  2020-07-31 18:12:00
# Teddi Fishman 🧑🏽 👩🏾 👨🏻 📷 📺 (she/her)          False  2020-07-25 03:25:03
# LynnZ                                         False  2020-08-22 00:17:02
# ChimpReports                                   True  2020-07-27 06:14:08
# Real business info                            False  2020-07-25 07:26:29
# CricketDiane                                  False  2020-07-26 04:25:08
# Liu Bao Bei                                   False  2020-07-25 06:17:46
# Roberto Jones                                 False  2020-07-25 03:31:53
#
#                                                                                    text  \
# GlobalPandemic.NET                    alert f b pledged keep source anonymous trump ...
# Social Distance Warrior                                                  trump pandemic
# Hotpage News                                   tucker state obvious drudge turned trump
# PMR DUNGUN                                                               sharing caring
# Mom3andRN                                         includes vet cop amp nurse want u amp
# TornadoNewsLinker                     along people like certain premiership football...
# Open Letters                                          sign bounty deliver copy official
# National Cyber Security                      fall scammer posing health worker pandemic
# James Starvoice                                                   made novel free enjoy
# Slim and Sugar                                    getting yet lied laughing u easy cont
# @holiness #VoteBlueNoMatterWho        evangelical support trump must examine see tru...
# 8min 46sec                                                                      instead
# www.THEPIGEONEXPRESS.com              two major city forced shutdown prevent anti go...
# Teddi Fishman 🧑🏽 👩🏾 👨🏻 📷 📺 (she/her)  watching umpteenth time wishing could go somew...
# LynnZ                                         snapshot country today million unemployed
# ChimpReports                                         member warned duplicity draw close
# Real business info                    trump sport founder talk stock market rebound ...
# CricketDiane                              one thing say really really raining real wind
# Liu Bao Bei                                              willing forego freedom liberty
# Roberto Jones                         lie dictatorship justify robbery amp launder p...
#
#                                                                                hashtags  \
# GlobalPandemic.NET                                                                  NaN
# Social Distance Warrior                                         ['MAGA2020', 'COVID19']
# Hotpage News                          ['Biden', 'Trump', 'GOP', 'Republican', 'Democ...
# PMR DUNGUN                            ['MalaysiaPrihatin', 'MerdekaMoment', 'Malaysi...
# Mom3andRN                                                                           NaN
# TornadoNewsLinker                     ['Globalists', 'SillyBilly', 'LadyGaga', 'Mado...
# Open Letters                                                                        NaN
# National Cyber Security                             ['coronavirus', 'scams', 'covid19']
# James Starvoice                          ['fantasy', 'thriller', 'fiction', 'suspense']
# Slim and Sugar                                                               ['WakeUp']
# @holiness #VoteBlueNoMatterWho                                                      NaN
# 8min 46sec                            ['uspoli', 'covid19', 'abuse', 'Ghislaine', 't...
# www.THEPIGEONEXPRESS.com                                         ['Zimbabwe', 'Harare']
# Teddi Fishman 🧑🏽 👩🏾 👨🏻 📷 📺 (she/her)                                       ['Hamilton']
# LynnZ                                                                               NaN
# ChimpReports                          ['NRM', 'Elections', 'ChimpReportsNews', 'Ugan...
# Real business info                                                                  NaN
# CricketDiane                                                               ['TexasGOP']
# Liu Bao Bei                                                                         NaN
# Roberto Jones                                                                       NaN
#
#                                                        source  is_retweet  \
# GlobalPandemic.NET                         GlobalPandemic.NET       False
# Social Distance Warrior               Cheap Bots, Done Quick!       False
# Hotpage News                                  Twitter Web App       False
# PMR DUNGUN                                Twitter for Android       False
# Mom3andRN                                  Twitter for iPhone       False
# TornadoNewsLinker                             Twitter Web App       False
# Open Letters                           Resistbot Open Letters       False
# National Cyber Security                         WordPress.com       False
# James Starvoice                               Twitter Web App       False
# Slim and Sugar                                Twitter Web App       False
# @holiness #VoteBlueNoMatterWho                Twitter Web App       False
# 8min 46sec                                          TweetDeck       False
# www.THEPIGEONEXPRESS.com                            TweetDeck       False
# Teddi Fishman 🧑🏽 👩🏾 👨🏻 📷 📺 (she/her)          Twitter Web App       False
# LynnZ                                      Twitter for iPhone       False
# ChimpReports                                  Twitter Web App       False
# Real business info                                      IFTTT       False
# CricketDiane                              Twitter for Android       False
# Liu Bao Bei                               Twitter for Android       False
# Roberto Jones                                 Twitter Web App       False
#
#                                       label
# GlobalPandemic.NET                        1
# Social Distance Warrior                   1
# Hotpage News                              1
# PMR DUNGUN                                1
# Mom3andRN                                 1
# TornadoNewsLinker                         1
# Open Letters                              1
# National Cyber Security                   1
# James Starvoice                           1
# Slim and Sugar                            1
# @holiness #VoteBlueNoMatterWho            1
# 8min 46sec                                1
# www.THEPIGEONEXPRESS.com                  1
# Teddi Fishman 🧑🏽 👩🏾 👨🏻 📷 📺 (she/her)      1
# LynnZ                                     1
# ChimpReports                              1
# Real business info                        1
# CricketDiane                              1
# Liu Bao Bei                               1
# Roberto Jones                             1

# %%
non_r_creators = list(nonrumours_creators.index)
non_r_creators_records = nonrumours[nonrumours['user_name'].isin(non_r_creators)]
non_r_creators_records = non_r_creators_records.drop_duplicates(subset='user_name', keep='first')
non_r_creators_records.index = non_r_creators_records.user_name
non_r_creators_records = non_r_creators_records.reindex(non_r_creators)
non_r_creators_records = pd.concat([nonrumours_creators, non_r_creators_records], axis=1)
non_r_creators_records

# 一半的人都认证过
# followers 在十万百万量级的多
# 其他没有friend , favourites的倾向性
# Out:
#                                          frequency  \
# Coronavirus Updates                            625
# GlobalPandemic.NET                             606
# covidnews.ch                                   401
# Open Letters                                   368
# Blood Donors India                             282
# Hindustan Times                                271
# IAM Platform                                   255
# Paperbirds_Coronavirus                         253
# IANS Tweets                                    238
# ANI                                            233
# Coronavirus Updates - Alexander Higgins        225
# OTV                                            218
# Dushyant Vachhani                              211
# ABS-CBN News                                   209
# Covid Data                                     208
# #IndiaFightsCorona                             199
# The New Indian Express                         195
# COVID Scale                                    191
# APO Group English                              179
# Sambad English                                 176
#
#                                                                        user_name  \
# Coronavirus Updates                                          Coronavirus Updates
# GlobalPandemic.NET                                            GlobalPandemic.NET
# covidnews.ch                                                        covidnews.ch
# Open Letters                                                        Open Letters
# Blood Donors India                                            Blood Donors India
# Hindustan Times                                                  Hindustan Times
# IAM Platform                                                        IAM Platform
# Paperbirds_Coronavirus                                    Paperbirds_Coronavirus
# IANS Tweets                                                          IANS Tweets
# ANI                                                                          ANI
# Coronavirus Updates - Alexander Higgins  Coronavirus Updates - Alexander Higgins
# OTV                                                                          OTV
# Dushyant Vachhani                                              Dushyant Vachhani
# ABS-CBN News                                                        ABS-CBN News
# Covid Data                                                            Covid Data
# #IndiaFightsCorona                                            #IndiaFightsCorona
# The New Indian Express                                    The New Indian Express
# COVID Scale                                                          COVID Scale
# APO Group English                                              APO Group English
# Sambad English                                                    Sambad English
#
#                                                 user_location  \
# Coronavirus Updates                                       NaN
# GlobalPandemic.NET                                  WORLDWIDE
# covidnews.ch                                      Switzerland
# Open Letters                             Text RESIST to 50409
# Blood Donors India                              Mumbai, India
# Hindustan Times                                         India
# IAM Platform                                        Worldwide
# Paperbirds_Coronavirus                                    NaN
# IANS Tweets                                         New Delhi
# ANI                                                     India
# Coronavirus Updates - Alexander Higgins                   NaN
# OTV                                       Bhubaneshwar, India
# Dushyant Vachhani                                         NaN
# ABS-CBN News                              Manila, Philippines
# Covid Data                                                NaN
# #IndiaFightsCorona                                        NaN
# The New Indian Express                                Chennai
# COVID Scale                                             Earth
# APO Group English                               #AFRICA #MENA
# Sambad English                                         Odisha
#
#                                                                           user_description  \
# Coronavirus Updates                      latest news statistic post update come stats o...
# GlobalPandemic.NET                       breaking news critical information survive out...
# covidnews.ch                                                    statistic information news
# Open Letters                             copy real letter delivered president congress ...
# Blood Donors India                       focused matching blood donor need follower con...
# Hindustan Times                          one largest medium company latest news around ...
# IAM Platform                             tool tip service platform power network go blo...
# Paperbirds_Coronavirus                   initiative committed deliver unbiased daily li...
# IANS Tweets                                                largest independent news agency
# ANI                                      news international multi medium news agency co...
# Coronavirus Updates - Alexander Higgins  independent citizen journalist aggregate repor...
# OTV                                      something unlikely elsewhere join u telegram f...
# Dushyant Vachhani
# ABS-CBN News                             story video multimedia worldwide ab news curre...
# Covid Data                                                         posting data web source
# #IndiaFightsCorona                                              official government update
# The New Indian Express                                            tweet breaking news view
# COVID Scale                              bot designed put pandemic effect united state ...
# APO Group English                              latest related release issued company fr pt
# Sambad English                           sun time cover breaking news alert feature art...
#
#                                                 user_created  user_followers  \
# Coronavirus Updates                      2020-03-07 12:52:51             433
# GlobalPandemic.NET                       2010-07-13 21:58:05           26108
# covidnews.ch                             2020-03-21 16:13:52             352
# Open Letters                             2017-12-06 22:18:07           17161
# Blood Donors India                       2008-12-23 07:55:39         1215920
# Hindustan Times                          2009-04-29 10:11:34         7647627
# IAM Platform                             2010-12-13 21:24:29           17815
# Paperbirds_Coronavirus                   2019-11-05 15:55:40             141
# IANS Tweets                              2010-05-08 13:21:45           52155
# ANI                                      2011-08-16 05:23:41         4515177
# Coronavirus Updates - Alexander Higgins  2010-05-02 03:52:20           17463
# OTV                                      2011-12-16 07:28:52          533537
# Dushyant Vachhani                        2010-02-11 00:42:17              32
# ABS-CBN News                             2008-08-16 10:09:33         7015048
# Covid Data                               2020-04-05 14:41:28              41
# #IndiaFightsCorona                       2020-03-31 07:41:35          100214
# The New Indian Express                   2009-12-05 09:24:55          445257
# COVID Scale                              2017-09-15 19:54:39             382
# APO Group English                        2011-02-22 09:09:45           10661
# Sambad English                           2013-11-12 08:17:29           34744
#
#                                          user_friends  user_favourites  \
# Coronavirus Updates                                 1                0
# GlobalPandemic.NET                              26003                2
# covidnews.ch                                     1881              148
# Open Letters                                        3                2
# Blood Donors India                               2047            19359
# Hindustan Times                                   126             2960
# IAM Platform                                    14941            65440
# Paperbirds_Coronavirus                              3               17
# IANS Tweets                                        45               65
# ANI                                                 0                0
# Coronavirus Updates - Alexander Higgins          6810             9897
# OTV                                               279              485
# Dushyant Vachhani                                  41               15
# ABS-CBN News                                     1071             1161
# Covid Data                                         14                0
# #IndiaFightsCorona                                 70             1748
# The New Indian Express                            552              540
# COVID Scale                                         2                2
# APO Group English                                   6             2037
# Sambad English                                      4                7
#
#                                          user_verified                 date  \
# Coronavirus Updates                              False  2020-07-25 12:22:11
# GlobalPandemic.NET                               False  2020-07-25 12:20:23
# covidnews.ch                                     False  2020-07-25 11:31:26
# Open Letters                                      True  2020-07-25 12:07:43
# Blood Donors India                                True  2020-07-25 12:26:26
# Hindustan Times                                   True  2020-07-25 11:19:29
# IAM Platform                                     False  2020-07-25 12:23:32
# Paperbirds_Coronavirus                           False  2020-07-25 11:37:32
# IANS Tweets                                       True  2020-07-25 11:23:25
# ANI                                               True  2020-07-25 12:09:27
# Coronavirus Updates - Alexander Higgins          False  2020-07-25 12:25:28
# OTV                                               True  2020-07-25 12:03:35
# Dushyant Vachhani                                False  2020-07-25 01:53:13
# ABS-CBN News                                      True  2020-07-25 10:30:00
# Covid Data                                       False  2020-07-25 12:00:20
# #IndiaFightsCorona                                True  2020-07-25 12:25:25
# The New Indian Express                            True  2020-07-25 11:55:55
# COVID Scale                                      False  2020-07-25 10:31:01
# APO Group English                                 True  2020-07-25 12:26:31
# Sambad English                                   False  2020-07-25 11:28:41
#
#                                                                                       text  \
# Coronavirus Updates                                                     new case new death
# GlobalPandemic.NET                       alert eye opener rep john remembered global pa...
# covidnews.ch                                                 student researcher brainstorm
# Open Letters                                     sign protect people deliver copy official
# Blood Donors India                       need type b positive hospital blood component ...
# Hindustan Times                          serum institute seek nod phase clinical trial ...
# IAM Platform                                 well tightens purse string ride pandemic read
# Paperbirds_Coronavirus                     news call school reopen downplaying health risk
# IANS Tweets                              per information offered financial support four...
# ANI                                      positive case patient recovered discharged mig...
# Coronavirus Updates - Alexander Higgins   u case death reported united state date new case
# OTV                                                                 portable device test r
# Dushyant Vachhani                                      early undoing small way start early
# ABS-CBN News                                             arrested breaking quarantine rule
# Covid Data                                                                        new data
# #IndiaFightsCorona                                 agree mask one powerful accessory fight
# The New Indian Express                   brought fore kinder new express magazine find ...
# COVID Scale                                                     watch died death worldwide
# APO Group English                                                       south update south
# Sambad English                                         four child among test positive city
#
#                                                                                   hashtags  \
# Coronavirus Updates                      ['coronavirus', 'CoronaVirusUpdate', 'COVID19'...
# GlobalPandemic.NET                                  ['Coronavirus', 'COVID19', 'Protests']
# covidnews.ch                               ['CoronaInfoCH', 'COVID19', 'corona', 'canada']
# Open Letters                                                                           NaN
# Blood Donors India                                           ['Kolar', 'Blood', 'COVID19']
# Hindustan Times                                                                ['COVID19']
# IAM Platform                                                                       ['cdc']
# Paperbirds_Coronavirus                              ['coronavirus', 'COVID19', '2019ncov']
# IANS Tweets                                                                        ['SFJ']
# ANI                                                                            ['COVID19']
# Coronavirus Updates - Alexander Higgins                                    ['CoronaVirus']
# OTV                                                   ['COVID19', 'CovidTesting', 'COVID']
# Dushyant Vachhani                                             ['Minnesota', 'Mississippi']
# ABS-CBN News                                              ['COVID19Quarantine', 'COVID19']
# Covid Data                                                      ['Coronavirus', 'COVID19']
# #IndiaFightsCorona                                                   ['IndiaFightsCorona']
# The New Indian Express                                                         ['COVID19']
# COVID Scale                                                                    ['COVID19']
# APO Group English                                                                      NaN
# Sambad English                                                       ['Odisha', 'COVID19']
#
#                                                          source  is_retweet  \
# Coronavirus Updates                             COVID19-Updates       False
# GlobalPandemic.NET                           GlobalPandemic.NET       False
# covidnews.ch                                          FS Poster       False
# Open Letters                             Resistbot Open Letters       False
# Blood Donors India                           Blood Donors India       False
# Hindustan Times                                       TweetDeck       False
# IAM Platform                                    IAMBLOG2TWITTER       False
# Paperbirds_Coronavirus                                  dlvr.it       False
# IANS Tweets                                     Twitter Web App       False
# ANI                                             Twitter Web App       False
# Coronavirus Updates - Alexander Higgins       Alexander Higgins       False
# OTV                                             Twitter Web App       False
# Dushyant Vachhani                               Twitter Web App       False
# ABS-CBN News                                          TweetDeck       False
# Covid Data                                      coronaData_Test       False
# #IndiaFightsCorona                              Twitter Web App       False
# The New Indian Express                          Twitter Web App       False
# COVID Scale                                         HN_Comments       False
# APO Group English                               Africa Newsroom       False
# Sambad English                                  Twitter Web App       False
#
#                                          label
# Coronavirus Updates                          0
# GlobalPandemic.NET                           0
# covidnews.ch                                 0
# Open Letters                                 0
# Blood Donors India                           0
# Hindustan Times                              0
# IAM Platform                                 0
# Paperbirds_Coronavirus                       0
# IANS Tweets                                  0
# ANI                                          0
# Coronavirus Updates - Alexander Higgins      0
# OTV                                          0
# Dushyant Vachhani                            0
# ABS-CBN News                                 0
# Covid Data                                   0
# #IndiaFightsCorona                           0
# The New Indian Express                       0
# COVID Scale                                  0
# APO Group English                            0
# Sambad English                               0

# %% [markdown]
# ##### User Followers Analysis

# %%
for i in range(len(rumours)):
    usr = rumours['user_name'][i]
    followers = rumours['user_followers'][i]
    if followers == max(list(rumours['user_followers'])):
        print(usr)
        print(followers)
        break

cgtn_cnt = 0
for i in range(len(rumours)):
    usr = rumours['user_name'][i]
    tweet = rumours['text'][i]
    if usr == 'CGTN':
        cgtn_cnt += 1
        print(tweet)
        
cgtn_cnt

# CGTN造谣四次，粉丝数做多  13892839 # 一千三百万
# Out:
# CGTN
# 13892839
# civil aviation recovers daily flight increase daily number civil aviation flight reached
# balloon released honor death
# official military exercise pushed back due
# smiley face captured blue sky northeastern japan city august air race
# 4

# %%
max_follower_unrumour = max(list(nonrumours['user_followers']))
for i in range(len(nonrumours)):
    usr = nonrumours['user_name'][i]
    tweet = nonrumours['text'][i]
    followers = nonrumours['user_followers'][i]
    if followers == max_follower_unrumour:
        print(usr)
        print(tweet)
        print(followers)
        break
# Out:
# CNN
# thought show hair please take seriously revealed
# 49442559

# %% [markdown]
# ##### Location Analysis

# %%
visualize_freq(rumours, 'user_location', 'Location', 20, 'Rumour', 'location-freq-rumour.png')
# Out:
# Index(['United States', 'USA', 'California, USA', 'Lagos, Nigeria',
#        'New York, NY', 'Los Angeles, CA', 'United Kingdom', 'Washington, DC',
#        'WORLDWIDE', 'Florida, USA', 'India', 'London', 'Texas, USA', 'Canada',
#        'Australia', 'London, England', 'Atlanta, GA',
#        'England, United Kingdom', 'San Diego, CA', 'New York, USA'],
#       dtype='object')

# %%
visualize_freq(nonrumours, 'user_location', 'Location', 20, 'Non-Rumour', 'location-freq-nonrumour.png')
# Out:
# Index(['India', 'United States', 'New Delhi, India', 'Mumbai, India',
#        'Washington, DC', 'London, England', 'United Kingdom', 'London',
#        'New York, NY', 'Australia', 'Worldwide', 'New Delhi', 'Canada', 'UK',
#        'South Africa', 'WORLDWIDE', 'Los Angeles, CA', 'USA', 'Global',
#        'Lagos, Nigeria'],
#       dtype='object')

# %%
rumour_locations = visualize_distribution(rumours, 'user_location', 'Location', 20, 'Rumour', 'location-rumour-bar.png')
rumour_locations

reconstruct_locations = ['USA', 'UK', 'Worldwide', 'India', 'Canada', 'Australia', 'Lagos', ]
reconstruct_locations_freq = [421+144+129+90+89+80+75+68+57+55+54, 86+70+62+57, 100, 72, 67, 66, 79]
# Out:
#                          frequency
# United States                  421
# USA                            144
# California, USA                129
# Lagos, Nigeria                 100
# New York, NY                    90
# Los Angeles, CA                 89
# United Kingdom                  86
# Washington, DC                  80
# WORLDWIDE                       79
# Florida, USA                    75
# India                           72
# London                          70
# Texas, USA                      68
# Canada                          67
# Australia                       66
# London, England                 62
# Atlanta, GA                     57
# England, United Kingdom         57
# San Diego, CA                   55
# New York, USA                   54

# %%
nonrumour_locations = visualize_distribution(nonrumours, 'user_location', 'Location', 20, 'Non-Rumour', 'location-nonrumour-bar.png')
nonrumour_locations
# Out:
#                   frequency
# India                  3669
# United States          2034
# New Delhi, India       1702
# Mumbai, India          1363
# Washington, DC         1274
# London, England        1207
# United Kingdom         1120
# London                 1033
# New York, NY            992
# Australia               898
# Worldwide               836
# New Delhi               806
# Canada                  768
# UK                      755
# South Africa            738
# WORLDWIDE               698
# Los Angeles, CA         687
# USA                     673
# Global                  670
# Lagos, Nigeria          631

# %%
reconstruct_locations = ['USA', 'UK', 'Worldwide', 'India', 'Canada', 'Australia', 'Lagos', ]
reconstruct_locations_freq = [421+144+129+90+89+80+75+68+57+55+54, 86+70+62+57, 100, 72, 67, 66, 79]
reconstruct_locations_freq = pd.DataFrame(reconstruct_locations_freq)
reconstruct_locations_freq.columns = ['frequency']
reconstruct_locations_freq.index = reconstruct_locations

cmap = plt.get_cmap('RdPu')
colors = [cmap(i) for i in np.linspace(0, 1, 8)]
fig = reconstruct_locations_freq['frequency'].plot.pie(ylabel='', autopct='%1.1f%%', figsize=(10,10), colors=colors, 
title='Top {} frequent {} Distribution in {} Tweets'.format(7, 'Country', 'Rumour')).get_figure()
fig.savefig('images/'+'rumour-country-pie.png', dpi=300, facecolor='w')

# %%
reconstruct_nonrumour_locations = ['India', 'USA', 'UK', 'Wordwide', 'Australia', 'Canada', 'South Africa',  'Lagos']
reconstruct_nonrumour_locations_freq = [3669+1702+1363+892+806, 2034+1274+697+673, 1207+1120+1033+755, 836+698+670, 898, 768, 738, 631]
reconstruct_nonrumour_locations_freq = pd.DataFrame(reconstruct_nonrumour_locations_freq)
reconstruct_nonrumour_locations_freq.columns = ['frequency']
reconstruct_nonrumour_locations_freq.index = reconstruct_nonrumour_locations

cmap = plt.get_cmap('RdPu')
colors = [cmap(i) for i in np.linspace(0, 1, 8)]
fig = reconstruct_nonrumour_locations_freq['frequency'].plot.pie(ylabel='', autopct='%1.1f%%', figsize=(10,10), colors=colors, 
title='Top {} frequent {} Distribution in {} Tweets'.format(8, 'Country', 'Non-Rumour')).get_figure()
fig.savefig('images/'+'country-nonrumour-pie.png', dpi=300, facecolor='w')

# %% [markdown]
# ##### User Description Analysis

# %%
visualize_freq(rumours, 'user_description', 'User Description', 40, 'Rumour', 'usr-des-freq-rumour.png')
# 看不出来啥
# Out:
# Index(['news', 'life', 'love', 'world', 'trump', 'u', 'right', 'tweet',
#        'writer', 'like', 'music', 'proud', 'follow', 'lover', 'time', 'fan',
#        'politics', 'people', 'one', 'truth', 'opinion', 'view', 'business',
#        'human', 'social', 'god', 'political', 'new', 'science', 'mom',
#        'author', 'endorsement', 'health', 'twitter', 'medium', 'sport',
#        'former', 'artist', 'good', 'day'],
#       dtype='object')

# %%
visualize_freq(nonrumours, 'user_description', 'User Description', 40, 'Non-Rumour', 'usr-des-freq-nonrumour.png')
# Out:
# Index(['news', 'health', 'world', 'official', 'u', 'life', 'tweet', 'view',
#        'business', 'follow', 'love', 'medium', 'account', 'endorsement',
#        'twitter', 'latest', 'people', 'service', 'update', 'information',
#        'social', 'global', 'research', 'opinion', 'time', 'one', 'writer',
#        'public', 'journalist', 'sport', 'politics', 'community', 'like',
#        'right', 'author', 'science', 'breaking', 'fan', 'help', 'work'],
#       dtype='object')

# %% [markdown]
# ##### User Verify Analysis

# %%
visualize_freq(rumours, 'user_verified', 'User Verified', 2, 'Rumour', 'usr-verify-freq-rumour.png')
# Out:
# Index([False, True], dtype='object')

# %%
visualize_freq(nonrumours, 'user_verified', 'User Verified', 2, 'Non-Rumour', 'usr-verify-freq-nonrumour.png')
# Out:
# Index([False, True], dtype='object')

# %%
visualize_distribution(rumours, 'user_verified', 'User Verfied Status', 2, 'Rumour', 'usr-verify-rumour-bar.png')
# 这里用饼图做分析
# Out:
#        frequency
# False      14254
# True         609

# %%
visualize_distribution(nonrumours, 'user_verified', 'User Verfied Status', 2, 'Rumour', 'usr-verify-nonumour-bar.png')
# 这里用饼图做分析
# Out:
#        frequency
# False     141759
# True       22486

# %% [markdown]
# ##### User Account Created Date Analysis

# %%
visualize_distribution(rumours, 'user_created', 'User Account Created Date', len(rumours), 'Rumour', 'usr-created-date-rumour-bar.png')
# Out:
#       frequency
# 2009       2291
# 2020       2007
# 2011       1341
# 2019       1160
# 2010       1147
# 2012       1052
# 2017       1010
# 2013        940
# 2016        860
# 2018        837
# 2014        774
# 2015        762
# 2008        581
# 2007         99
# 2006          2

# %%
visualize_distribution(nonrumours, 'user_created', 'User Account Created Date', len(nonrumours), 'Non-Rumour', 'usr-created-date-nonrumour-bar.png')
# 基本爷看不出来啥
# Out:
#       frequency
# 2009      26740
# 2020      20421
# 2010      15775
# 2011      15420
# 2012      12481
# 2019      10954
# 2013      10626
# 2017       9601
# 2014       8953
# 2015       8878
# 2016       8485
# 2018       8149
# 2008       6446
# 2007       1280
# 2006         35
# 1970          1

# %% [markdown]
# #### Sentiment Analysis

# %%
visualize_distribution(rumours, 'sentiment', 'Sentiment', 2, 'Rumour', 'rumour-sentiment.png')
# Out:
#           frequency
# NEGATIVE      10345
# POSITIVE       4518

# %%
visualize_distribution(nonrumours, 'sentiment', 'Sentiment', 2, 'Non-Rumour', 'rumour-sentiment.png')
# Out:
#           frequency
# NEGATIVE      94341
# POSITIVE      69904

# %% [markdown]
# ##### Source Analysis

# %%
visualize_distribution(rumours, 'source', 'Source', 5, 'Rumour', 'rumour-source.png')
# Out:
#                      frequency
# Twitter Web App           4544
# Twitter for Android       4148
# Twitter for iPhone        4114
# Twitter for iPad           605
# TweetDeck                  277

# %%
visualize_distribution(nonrumours, 'source', 'Source', 5, 'Non-Rumour', 'nonrumour-source.png')
# 差距不明显
# Out:
#                      frequency
# Twitter Web App          52347
# Twitter for Android      36031
# Twitter for iPhone       31358
# TweetDeck                 8266
# Hootsuite Inc.            7156

# %%
len(Counter(covid_data['source'])) # 611种不同的source
# Out:
# 611

# %%
covid_data.columns
# is_retweet 全部都是False 做不了分析
# Out:
# Index(['user_name', 'user_location', 'user_description', 'user_created',
#        'user_followers', 'user_friends', 'user_favourites', 'user_verified',
#        'date', 'text', 'hashtags', 'source', 'is_retweet', 'label',
#        'sentiment'],
#       dtype='object')
